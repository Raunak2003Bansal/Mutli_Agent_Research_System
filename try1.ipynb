# %%
print("hello world")
# Out:
# hello world

# %%
from langchain_openrouter import ChatOpenRouter
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.7,
    max_retries=3
)

# Now you can use it just like your previous models!
response = llm.invoke("Hello Gemini, write a summary about...")
print(response.content)
# Out:
# Hello! I can definitely help you with a summary.
#
# To do that, I just need you to tell me **what topic, article, book, event, or text** you'd like the summary to be about.
#
# For example, you could say:
#
# *   "Write a summary about the history of artificial intelligence."
# *   "Summarize the main points of the attached article on renewable energy."
# *   "Give me a summary of the plot of 'Moby Dick'."
# *   "Summarize the key findings of the latest IPCC report."
#
# Once you provide the topic, I'll be happy to create a summary for you!

# %%
from agents import writer_agent

# %%
result = writer_agent.invoke({"messages": [("user", "News on Claude recent model Mythos")]})

# %%
print(result)
# Out:
# {'messages': [HumanMessage(content='News on Claude recent model Mythos', additional_kwargs={}, response_metadata={}, id='f297167c-6e50-4057-8c8f-be1785ac9765'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'web_search', 'arguments': '{"query": "Claude AI recent model Mythos news"}'}, '__gemini_function_call_thought_signatures__': {'bd26bd62-43e9-48ba-9019-8f89d06393b3': '...'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019eca06-f609-77f0-add1-40a9115562cc-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'Claude AI recent model Mythos news'}, 'id': 'bd26bd62-43e9-48ba-9019-8f89d06393b3', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1086, 'output_tokens': 80, 'total_tokens': 1166, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 59}}), ToolMessage(content='Title: New super-powered Claude m
# ...

# %%
print(result["messages"][-1])
# Out:
# content='Returning structured response: introduction="Anthropic\'s Claude Mythos 5 represents a significant advancement in artificial intelligence, particularly in the domains of cybersecurity and biological research. Initially met with both anticipation and concern due to its advanced capabilities, Mythos 5 has been developed with a strong emphasis on addressing critical global challenges while also navigating potential risks. This report will detail the model\'s key features, its current deployment status, and the inherent safeguards implemented by Anthropic to manage its powerful functionalities." key_findings=[KeyFinding(subheading=\'Unprecedented Capabilities in Cybersecurity and Biology\', explanation="Claude Mythos 5 is heralded as Anthropic\'s most capable model, demonstrating significant gains in cybersecurity, biology, and healthcare benchmarks. It has been instrumental in Project Glasswing, an initiative involving major tech companies and organizations like Amazon Web Serv
# ...
